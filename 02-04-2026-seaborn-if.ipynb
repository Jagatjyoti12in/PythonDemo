# %%
print("02-04-2026")
# Out:
# 02-04-2026

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\Jagatjyoti\Jagat_Code\31-03-2026\data.xlsx")
print(df.head())
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize']= 6,2

import warnings
warnings.filterwarnings('ignore') # as error
df ['InternetUsers']


#df = pd.read_excel(r"C:\Users\Jagatjyoti\Jagat_Code\31-03-2026\data.xlsx")
#print(df.head())
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
vist1 = sns.distplot(df['InternetUsers'])
plt.show()

# %%
vist2 = sns.displot(df.InternetUsers)
plt.show()

# %%
vist2 = sns.distplot(df['InternetUsers'],bins =15)

# %%
#Box Plot
vis4 = sns.boxplot(data = df, x ='IncomeGroup', y = 'BirthRate')
plt.show()

# %%
vis5 = sns.lmplot(data = df, x="InternetUsers", y="BirthRate")
plt.show()

# %%
vis5 = sns.lmplot(data = df, x="InternetUsers", y="BirthRate", fit_reg =False)
plt.show()

# %%
vis6 = sns.lmplot(data = df, x="InternetUsers", y="BirthRate", fit_reg =False)
plt.show()

# %%
vis8 = sns.lmplot(data = df, x="InternetUsers", y="BirthRate", fit_reg =True)
plt.show()

# %%
#Hue for color
vis8 = sns.lmplot(data = df, x="InternetUsers", y="BirthRate", fit_reg =False, hue='IncomeGroup')
plt.show()

# %%
#Hue for color
vis8 = sns.lmplot(data = df, x="InternetUsers", y="BirthRate", fit_reg =True, hue='IncomeGroup')
plt.show()

# %%
# Advance Python
if True:
    print("Data Science") # By defaut indentation is four space
# Out:
# Data Science

# %%
# Advance Python
if True:
print("Data Science")
# Out:
#   Cell In[42], line 3
#     print("Data Science")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
# Advance Python
if True:
 print("Data Science")
# Out:
# Data Science

# %%
# Advance Python
if True:
 print("Data Science")
     print("Bye for now")
# Out:
#   Cell In[44], line 4
#     print("Bye for now")
#     ^
# IndentationError: unexpected indent

# %%
# Advance Python
if True:
 print("Data Science")
print("Bye for now")
# Out:
# Data Science
# Bye for now

# %%
# Advance Python
if True:
    print("Data Science")
else:
    print("Bye for now")
# Out:
# Data Science

# %%
# Advance Python check even or odd number
x=4
r= x%2
if r==0:
    print(" Even")
else:
    print("Odd")
# Out:
#  Even

# %%
# Advance Python check even or odd number
x=5
r= x%2
if r==0:
    print(" Even")
else:
    print("Odd")
# Out:
# Odd

# %%
# Advance Python check even or odd number
# Do not right multiple if'
x=6
r= x%2
if r==0:
    print(" Even")
if r==1:
    print("Odd")
# Out:
#  Even
