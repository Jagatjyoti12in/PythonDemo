# %% [markdown]
# #

# %%
25
# Out:
# 25

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(30)
# Out:
# '0b11110'

# %%
int(0b11110)
# Out:
# 30

# %%
oct(25)
# Out:
# '0o31'

# %%
int(0o31)
# Out:
# 25

# %%
hex(16)
# Out:
# '0x10'

# %%
print(0xa)
print(0xb)
print(0xc)
print(0xd)
print(0xe)
print(0xf)
# Out:
# 10
# 11
# 12
# 13
# 14
# 15

# %%
hex(10)
# Out:
# '0xa'

# %%
~3
# Out:
# -4

# %%
16
# Out:
# 16

# %%
~16
# Out:
# -17

# %%
~-16
# Out:
# 15

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
bin(20)
# Out:
# '0b10100'

# %%
12 & 20
# Out:
# 4

# %%
12 ^ 13
# Out:
# 1

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(30)
# Out:
# '0b11110'

# %%
25 ^ 30
# Out:
# 7

# %%
12<<1
# Out:
# 24

# %%
12<<2
# Out:
# 48

# %%
bin(25)
# Out:
# '0b11001'

# %%
binary = "1100"
decimal = int(binary, 2)
print(decimal)  # Output: 10
# Out:
# 12

# %%
12>>1
# Out:
# 6

# %%
13>>3
# Out:
# 1

# %%
13>>4
# Out:
# 0

# %%
13>>5
# Out:
# 0

# %%
13>>7
# Out:
# 0

# %%
name1="a"
name2 ="A"
print( name1 >  name2)
# Out:
# True

# %%
num1=10
num2=20
add=num1 + num2
print(' The addition of {} and {} is = {}'.format(num1,num2,add))
# Out:
#  The addition of 10 and 20 is = 30

# %%
name ='Python'
age=20
city='Hyderabad'
print('my {} is and aga is {} and i am from{}'.format(name,age,city))
# Out:
# my Python is and aga is 20 and i am fromHyderabad

# %%
num4 = 10
num5 = 20

add = num4 + num5

print(f'The addition of {num4} and {num5} is = {add}')
# Out:
# The addition of 10 and 20 is = 30
