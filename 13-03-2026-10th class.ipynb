# %%
# last

# %%
bool('zero')
# Out:
# True

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(2.3)
# Out:
# (2.3+0j)

# %%
complex(2.3,4.5)
# Out:
# (2.3+4.5j)

# %%
complex(23,4.5)
# Out:
# (23+4.5j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex('10',20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 complex('10',20)
#
# TypeError: complex() can't take second arg if first is a string

# %%
str(100)
# Out:
# '100'

# %%
str(2.3)
# Out:
# '2.3'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %%
str(2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 str(2,3)
#
# TypeError: str() argument 'encoding' must be str, not int

# %% [markdown]
# # x1,y1 =10,5
# x1+y1

# %%
2**3
# Out:
# 8

# %%
x1,y1 =10,5
x1+y1
# Out:
# 15

# %%
#Assignment Operator

# %%
x=2

# %%
x = x+2

# %%
x *=2

# %%
print(x *= 2)
# Out:
#   Cell In[52], line 1
#     print(x *= 2)
#             ^
# SyntaxError: invalid syntax

# %%
n=7
n
# Out:
# 7

# %%
m = -n
m
# Out:
# -7

# %%
a =5
b=6
a<b
# Out:
# True

# %%
a> b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a=b
a==b
# Out:
# True

# %%
c=5
d=7
c ==d
# Out:
# False

# %%
print(c)
print(d)
# Out:
# 5
# 7

# %%
c!=d
# Out:
# True

# %%
c>d
# Out:
# False

# %%
c>=d
# Out:
# False

# %%
c<=d
# Out:
# True

# %%
a =5
b= 4

# %%
a<8 and b<5
# Out:
# True

# %%
a<8 or b<5
# Out:
# True

# %%
a<8 and b<2
# Out:
# False

# %%
a>8 and b<2
# Out:
# False

# %%
x = True
not x
# Out:
# False

# %%
#Number System

# %%
-True
# Out:
# -1

# %%
-False
# Out:
# 0

# %%
10+3*2-1
# Out:
# 15

# %%
10+(3*2)-1
# Out:
# 15

# %%
10+3*(2-1)
# Out:
# 13

# %%
a =10
b=20
a
b
# Out:
# 20

# %%
a =10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
print(10)
print(10,20)
print('python')
print(10,20,'python')
# Out:
# 10
# 10 20
# python
# 10 20 python

# %%
num1= 20
num2 =30
add = num1 + num2
print(add)
print('The addition of', num1, 'and', num2, 'is', add)
# Out:
# 50
# The addition of 20 and 30 is 50

# %%
#Print result with String 
#LLM model is got hallucination or confusion

# %%
num1= 20
age  =30
add = num1 + num2
print(add)
