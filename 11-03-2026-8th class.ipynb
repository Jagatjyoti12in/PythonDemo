# %%
c = 1+2j
c1 = 3+4j
c+c1
# Out:
# (4+6j)

# %%
#String
'welcome to Naresh It  & Request wveryone to please subscribe nareshit yputube , insta'
# Out:
# 'welcome to Naresh It  & Request wveryone to please subscribe nareshit yputube , insta'

# %%
'''welcome to Naresh It  & Request wveryone to please subscribe nareshit yputube , insta'''
# Out:
# 'welcome to Naresh It  & Request wveryone to please subscribe nareshit yputube , insta'

# %%
"welcome to Naresh It  & Request wveryone to please subscribe nareshit yputube , insta"
# Out:
# 'welcome to Naresh It  & Request wveryone to please subscribe nareshit yputube , insta'

# %%
'''welcome to Naresh It 
& Request wveryone to please subscribe 
nareshit youtube , insta'''
# Out:
# 'welcome to Naresh It \n& Request wveryone to please subscribe \nnareshit youtube , insta'

# %%
str = "Hello Python"
str
# Out:
# 'Hello Python'

# %%
s = 'python'
s[0]
s[5]
s[-1]
# Out:
# 'n'

# %%
s1="Welcome"
s1[3]
# Out:
# 'c'

# %%
s1[-3]
# Out:
# 'o'

# %%
s1[-5]
# Out:
# 'l'

# %%
len(s1)
# Out:
# 7

# %%
s ='welcome'
s
# Out:
# 'welcome'

# %%
s1
# Out:
# 'Welcome'

# %%
s1[:]
# Out:
# 'Welcome'

# %%
s1[1:3]
# Out:
# 'el'

# %%
s1
# Out:
# 'Welcome'

# %%
s1[1:4] # s1= 'Welcome', start with index number 1 that is e until index 4-1[0,1,2,3]
# Out:
# 'elc'

# %%
s1[:]
# Out:
# 'Welcome'

# %%
s1[3:]
# Out:
# 'come'

# %%
s2= 'nareshtechnology'
len(s2)
# Out:
# 16

# %%
s2[:]
# Out:
# 'nareshtechnology'

# %%
s2[:3]
# Out:
# 'nar'

# %%
s2
# Out:
# 'nareshtechnology'

# %%
s2[:6] #its comming until 5th index value as starts from 0,1,2,3,4,5 total 6number of letters
# Out:
# 'naresh'

# %%
s2[:100]
# Out:
# 'nareshtechnology'

# %%
p=20
q=20
r=20
print(id(p))
id(q)
# Out:
# 140714106537352
# 140714106537352
