# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
# Load image
img = Image.open("D:/EXPERIENCE/DL_PAN_Passport_&Photo_Jagatjyoti/p1.jpg")   # replace with your image path
img
#type(img)
# Convert to NumPy array
img_array = np.array(img)
print("Image array:\n", img_array)
print("Shape:", img_array.shape)

plt.imshow(img)
plt.show()
# Out:
# Image array:
#  [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[209 218 223]
#   [210 219 224]
#   [211 220 225]
#   ...
#   [210 217 223]
#   [242 247 251]
#   [246 250 253]]
#
#  [[251 255 255]
#   [251 255 255]
#   [251 255 255]
#   ...
#   [249 254 255]
#   [251 255 255]
#   [252 255 255]]
#
#  [[250 254 255]
#   [250 254 255]
#   [249 253 254]
#   ...
#   [242 247 251]
#   [252 255 255]
#   [239 243 246]]]
