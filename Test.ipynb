# %%
print("Hello")
# Out:
# Hello

# %%
n= 123

sum =0
while n > 0:
        sum += n % 10
        n //= 10
print(sum)
# Out:
# 6

# %%
list = ["Data Science", "Machine Learning", "Deep Learning", "Artificial Intelligence"]
result ="_".join(list)
print(result)
# Out:
# Data Science_Machine Learning_Deep Learning_Artificial Intelligence

# %%
s =("apple, banana, cherry")
lst = s.split(", ")
print(len(lst),lst[1])
# Out:
# 3 banana

# %%
list =[1,2,3]

print(list*2)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
s={1,2,3,4}

print(len(s))
# Out:
# 4

# %%
d = {"name": "Alice", "age": 30, "city": "New York"}

print(d["name1"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 3
#       1 d = {"name": "Alice", "age": 30, "city": "New York"}
# ----> 3 print(d["name1"])
#
# KeyError: 'name1'

# %%
x ={1,2,3}

y = {3,4,5}
print( x& y, x|y)
# Out:
# {3} {1, 2, 3, 4, 5}

# %%
import numpy as np

arry =np.array([1,2,3,4])
res = np.where(arry>2,10,0)
print(res)
# Out:
# [ 0  0 10 10]

# %%
n=5

for i in range(2, n):
    print("i=",i)
    if n%2 == 0:
       print("n=",n)
       print("Print not prime")
       break
else:
    print("Prime")

# %%
for i in range(1, 10):
    if i==6:
        print("i=",i)
        break
# Out:
# i= 6

# %%
""
