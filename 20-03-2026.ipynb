# %%
#Datastructure

# %%
# List Datastructrure in Python

# %%
l=[]
print(l)
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
print(type(l))
# Out:
# <class 'list'>

# %%
l.append(10)
l
# Out:
# [10]

# %%
l.append(20)
l.append(30)
l.append(40)
l.append(50)
l
# Out:
# [10, 20, 30, 40, 50]

# %%
len(l)
# Out:
# 9

# %%
l.clear()

# %%
l1=[10,'2.3',1+2j,True,'nit',[1,2,3]]

# %%
l1
# Out:
# [10, '2.3', (1+2j), True, 'nit', [1, 2, 3]]

# %%
len(l1)
# Out:
# 6

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 50]
# [10, '2.3', (1+2j), True, 'nit', [1, 2, 3]]

# %%
print(id(l))
print(id(l1))
# Out:
# 2425017249920
# 2425020190016

# %%
l2= l.copy()
l2
# Out:
# [10, 20, 30, 40, 50]

# %%
print(id(l))
print(id(l1))
print(id(l2))
# Out:
# 2425017249920
# 2425020190016
# 2425033037120

# %%
len(l2)
# Out:
# 5

# %%
l2.clear()

# %%
len(l2)
# Out:
# 0

# %%
del l2

# %%
len(l2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 len(l2)
#
# NameError: name 'l2' is not defined

# %%
l.count(20)
# Out:
# 1

# %%
l.count(20)
# Out:
# 1

# %%
l.count(100)
# Out:
# 0

# %%
a =[1,2,3]
b=[4,5,6]
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l2 = []
l2
# Out:
# []

# %%
l2.extend(l)

# %%
l2
# Out:
# [10, 20, 30, 40, 50]

# %%
print(l)
print(l1)
print(l2)
# Out:
# [10, 20, 30, 40, 50]
# [10, '2.3', (1+2j), True, 'nit', [1, 2, 3]]
# [10, 20, 30, 40, 50]

# %%
l[0]
# Out:
# 10

# %%
l[0]=100

# %%
l
# Out:
# [100, 20, 30, 40, 50]

# %%
job=[5000]
job[0]
job[0]=10000
job
# Out:
# [10000]

# %%
l[4]=500
l
# Out:
# [100, 20, 30, 40, 500]

# %%
l.index(100)
# Out:
# 0

# %%
l.append(100)

# %%
l
# Out:
# [100, 20, 30, 40, 500, 100, 100]

# %%
l.index(100) # Even multiple 100 value present in the list still it print the first occurance index
# Out:
# 0

# %%
l.insrt()

# %%
l.insert(2,25)
l
# Out:
# [100, 20, 25, 30, 40, 500, 100, 100]

# %%
l2
# Out:
# [10, 20, 30, 40, 50]

# %%
l2.pop()
# Out:
# 50

# %%
l2
# Out:
# [10, 20, 30, 40]

# %%
l2.pop(2)
# Out:
# 30

# %%
l2
# Out:
# [10, 20, 40]

# %%
l2.remove(40)

# %%
l2
# Out:
# [10, 20]

# %%
l2.reverse()

# %%
l2
# Out:
# [20, 10]

# %%
l2.sort()

# %%
l2
# Out:
# [10, 20]

# %%
l2.sort(reverse =True)
l2
# Out:
# [20, 10]

# %%
l2.sort(reverse =False)
l2
# Out:
# [10, 20]

# %%
l3=[10,20,[2,3],3]
l3[2]=[2]
l3
# Out:
# [10, 20, [2], 3]

# %%
l3=[10,20,[2,3,4,5],3]
l3[2]=[2,4,5]
l3
# Out:
# [10, 20, [2, 4, 5], 3]

# %%
l4=[10,20,30,40,50,500,100]
10 in l4
# Out:
# True

# %%
for i in l4:
  print(i)
# Out:
# 10
# 20
# 30
# 40
# 50
# 500
# 100
