# %%
print("06th April 2026 Class")
# Out:
# 06th April 2026 Class

# %%
import streamlit as st
st.write("Welcome to Streamlit")
# Out:
# 2026-04-06 11:03:37.931 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 11:03:37.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-04-06 11:03:37.934 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import streamlit as st
st.write("Welcome to Streamlit")
