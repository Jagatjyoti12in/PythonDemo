# %%
_aa= 20
_aa
# Out:
# 20

# %%
_
# Out:
# 20

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
i = 5
i
type(i)
# Out:
# int

# %%
id(i)
# Out:
# 140735239799720

# %%
f=112.45
f
type(f)
# Out:
# float

# %%
print(10+5}
print(10-5)
10*5
# Out:
# 50

# %%
f1=2.4e1
f1
# Out:
# 24.0

# %%
f2 =3.5e3
f2
# Out:
# 3500.0

# %%
b= True
b
# Out:
# True

# %%
create an image of god wearing black spakes
# Out:
# 2

# %%
False/True
# Out:
# 0.0

# %%
int(True)
# Out:
# 1

# %%
True + False
# Out:
# 1

# %%
complex
# Out:
# complex

# %%
c= 10+20j
type(c)
# Out:
# complex

# %%
c
c.real
c.imag
# Out:
# 20.0
